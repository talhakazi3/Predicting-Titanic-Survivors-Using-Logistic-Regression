# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import stats
import seaborn as sns
import Omkar_Stats as Om

# %%
df=pd.read_csv('Titanic-Dataset.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
sns.countplot(data=df, x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.pairplot(df)

# %%
#1.Remove irrelevant columns from dataset
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.displot(df['Age'])

# %%
df.groupby('Pclass')['Age'].median()
# Out:
# Pclass
# 1    37.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
sns.boxplot(data=df,x ='Pclass', y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.heatmap(df.dropna().corr(numeric_only=True),annot=True,cmap='coolwarm',vmin=-1)
# Out:
# <Axes: >

# %%
df.groupby('Pclass')['Age'].transform('mean')
# Out:
# 0      25.140620
# 1      38.233441
# 2      25.140620
# 3      38.233441
# 4      25.140620
#          ...
# 886    29.877630
# 887    38.233441
# 888    25.140620
# 889    38.233441
# 890    25.140620
# Name: Age, Length: 891, dtype: float64

# %%
df.groupby('Pclass')['Age'].transform('median')
# Out:
# 0      24.0
# 1      37.0
# 2      24.0
# 3      37.0
# 4      24.0
#        ...
# 886    29.0
# 887    37.0
# 888    24.0
# 889    37.0
# 890    24.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age']=df['Age'].fillna(df.groupby('Pclass')['Age'].transform('median'))

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df['Sex']=df['Sex'].map({'male':0, 'female':1})

# %%
round((df.isnull().sum()/len(df))*100, 2)
# Out:
# Survived     0.00
# Pclass       0.00
# Name         0.00
# Sex          0.00
# Age          0.00
# SibSp        0.00
# Parch        0.00
# Ticket       0.00
# Fare         0.00
# Cabin       77.10
# Embarked     0.22
# dtype: float64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked']=df['Embarked'].fillna('S')

# %%
df['Embarked']=df['Embarked'].map({'S':0, 'C':1, 'Q':2})

# %%
df['Cabin'][df['Pclass']==3].isnull().sum()
# Out:
# 479

# %%
df['Cabin']=df['Cabin'].isnull().astype(int)

# %%
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    0
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2           1       3                             Heikkinen, Miss. Laina    1
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4           0       3                           Allen, Mr. William Henry    0
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    0
# 887         1       1                       Graham, Miss. Margaret Edith    1
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    1
# 889         1       1                              Behr, Mr. Karl Howell    0
# 890         0       3                                Dooley, Mr. Patrick    0
#
# ...

# %%
import Omkar_Stats as om
for col_name in df.select_dtypes('number').columns:
    print('Stats for',col_name)
    st=om.cal_stats(df[col_name])
    st.everything()
    print('-'*50)
# Out:
# Stats for Survived
# Total Sum: 342
# Total Count: 891
# Maximum Value: 1
# Minimum Value: 0
# Range: 1
# Average: 0.3838383838383838
# Median: 0.0
# Mode: 0
# Variance: 0.2365064789307223
# Standard Deviation: 0.48631931786710086
# Quartile 1: 0.0
# Quartile 3: 1.0
# IQR: 1.0
# Lower Whisker: -1.5
# Upper Whisker: 2.5
# Skewness: 0.4769134537964489
# Kurtosis: -1.7745414090641847
# Number of Outliers: 0
# Likely Does NOT Follow Normal Distribution
# 95% Confidence Interval: (0.352, 0.416)
# 97% Confidence Interval: (0.348, 0.419)
# 99% Confidence Interval: (0.342, 0.426)
# 1 Standard Deviation Range: (-0.10 to 0.87) --> 61.62% of data
# 2 Standard Deviation Range: (-0.59 to 1.36) --> 100.00% of data
# 3 Standard Deviation Range: (-1.08 to 1.84) --> 100.00% of data
# Unique Count: 2
# Detected Discrete Data
# --------------------------------------------------
# Stats for Pclass
# Total Sum: 2057
# Total Count: 891
# Maximum Value: 3
# Minimum Value: 1
# Range: 2
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    0
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2           1       3                             Heikkinen, Miss. Laina    1
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4           0       3                           Allen, Mr. William Henry    0
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas    0
# 887         1       1                       Graham, Miss. Margaret Edith    1
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"    1
# 889         1       1                              Behr, Mr. Karl Howell    0
# 890         0       3                                Dooley, Mr. Patrick    0
#
# ...

# %%
sns.heatmap(df.dropna().corr(numeric_only=True),annot=True,cmap='coolwarm',vmin=-1)
# Out:
# <Axes: >

# %%
df['Fare'][df['Fare']>250]=250

# %%
df[df['Fare']==df['Fare'].max()]
# Out:
#      Survived  Pclass                                   Name  Sex   Age  \
# 27          0       1         Fortune, Mr. Charles Alexander    0  19.0
# 88          1       1             Fortune, Miss. Mabel Helen    1  23.0
# 258         1       1                       Ward, Miss. Anna    1  35.0
# 311         1       1             Ryerson, Miss. Emily Borie    1  18.0
# 341         1       1         Fortune, Miss. Alice Elizabeth    1  24.0
# 438         0       1                      Fortune, Mr. Mark    0  64.0
# 679         1       1     Cardeza, Mr. Thomas Drake Martinez    0  36.0
# 737         1       1                 Lesurer, Mr. Gustave J    0  35.0
# 742         1       1  Ryerson, Miss. Susan Parker "Suzette"    1  21.0
#
#      SibSp  Parch    Ticket   Fare  Cabin  Embarked
# 27       3      2     19950  250.0      0         0
# 88       3      2     19950  250.0      0         0
# 258      0      0  PC 17755  250.0      1         1
# ...

# %%
sns.displot(df['Fare'])

# %%
#fAMILY SIZE
df['Family']=df['Parch'] + df['SibSp'] + 1

# %%
# is alone
df['IsAlone']=(df['Family']==1).astype(int)

# %%
df['IsAlone'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IsAlone'>

# %%
# fare per person
df['FarePerPerson'] = df['Fare']/df['Family']

# %%
# pclass* fare
df['FareByClass'] = df['Pclass']*df['Fare']

# %%
df.drop(['Name','Ticket'],axis=1,inplace=True)

# %%
df['Fare']=np.log1p(df['Fare'])

# %%
np.log1p(200)
# Out:
# 5.303304908059076

# %%
X=df.drop('Survived', axis=1)
y=df['Survived']

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
X=ss.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=100)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.coef_
# Out:
# array([[-0.64027942,  1.27295084, -0.5807171 , -0.37311578, -0.12885483,
#          0.29297656, -0.30057253,  0.07613812, -0.31938555, -0.35042299,
#         -0.02978877, -0.06166819]])

# %%
y_pred_train=lr.predict(X_train)

# %%
y_pred_test=lr.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print('Train classification report')
print(classification_report(y_train, y_pred_train))
print('Test classification report')
print(classification_report(y_test, y_pred_test))
# Out:
# Train classification report
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       445
#            1       0.76      0.72      0.74       267
#
#     accuracy                           0.81       712
#    macro avg       0.80      0.79      0.80       712
# weighted avg       0.81      0.81      0.81       712
#
# Test classification report
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       104
#            1       0.80      0.73      0.76        75
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.80      0.80       179
# weighted avg       0.81      0.81      0.81       179
